# %%
import pandas as pd

# %%
df= pd.read_csv("/content/2- share-of-global-plastic-waste-emitted-to-the-ocean.csv")
df2= pd.read_csv("/content/1- global-plastics-production.csv")
df3= pd.read_csv("/content/3- share-plastic-fate.csv")
df4= pd.read_csv("/content/4- mismanaged-plastic-waste-per-capita.csv")

# %%
df.head(10)
# Out:
#                 Entity     Code  Year  \
# 0               Africa  unknown  2019
# 1              Albania      ALB  2019
# 2              Algeria      DZA  2019
# 3               Angola      AGO  2019
# 4  Antigua and Barbuda      ATG  2019
# 5            Argentina      ARG  2019
# 6                 Asia  unknown  2019
# 7            Australia      AUS  2019
# 8              Bahamas      BHS  2019
# 9              Bahrain      BHR  2019
#
#    Share of global plastics emitted to ocean
# 0                                   7.989317
# 1                                   0.159782
# 2                                   0.589510
# 3                                   0.087804
# 4                                   0.000204
# 5                                   0.422376
# 6                                  80.993570
# 7                                   0.003267
# 8                                   0.002042
# 9                                   0.000000

# %%
df["Code"]= df["Code"].fillna("unknown")

# %%
df.isnull().sum()
# Out:
# Entity                                       0
# Code                                         0
# Year                                         0
# Share of global plastics emitted to ocean    0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#                   Entity    Code  Year  \
# 0                 Africa  uknown  2019
# 1                Albania     ALB  2019
# 2                Algeria     DZA  2019
# 3                 Angola     AGO  2019
# 4    Antigua and Barbuda     ATG  2019
# ..                   ...     ...   ...
# 165            Venezuela     VEN  2019
# 166              Vietnam     VNM  2019
# 167       Western Sahara     ESH  2019
# 168                Yemen     YEM  2019
# 169             Zimbabwe     ZWE  2019
#
#      Share of global plastics emitted to ocean
# 0                                     7.989317
# 1                                     0.159782
# 2                                     0.589510
# 3                                     0.087804
# 4                                     0.000204
# ..                                         ...
# 165                                   0.611359
# 166                                   2.881287
# 167                                   0.003880
# 168                                   0.025729
# 169                                   0.000000
#
# [170 rows x 4 columns]

# %%
df2.head()
# Out:
#   Entity      Code  Year  Annual plastic production between 1950 and 2019
# 0  World  OWID_WRL  1950                                          2000000
# 1  World  OWID_WRL  1951                                          2000000
# 2  World  OWID_WRL  1952                                          2000000
# 3  World  OWID_WRL  1953                                          3000000
# 4  World  OWID_WRL  1954                                          3000000

# %%
df2.shape
# Out:
# (69, 4)

# %%
df2.isnull().sum()
# Out:
# Entity                                             0
# Code                                               0
# Year                                               0
# Annual plastic production between 1950 and 2019    0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Entity                                                         0
# Code                                                          30
# Year                                                           0
# Share of waste recycled from total regional waste              0
# Share of waste incinerated from total regional waste           0
# Share of littered and mismanaged from total regional waste     0
# Share of waste landfilled from total regional waste            0
# dtype: int64

# %%
df3["Code"]= df["Code"].fillna("uknown")

# %%
df =df.replace("uknown","unknown")

# %%
df4["Code"] = df4["Code"].fillna("unknown")

# %%
df.to_csv("cleaned share")

# %%
df2.to_csv("cleaned global production")

# %%
df3.to_csv("cleaned share plastic fate")

# %%
df4.to_csv("cleaned mismanaged")
